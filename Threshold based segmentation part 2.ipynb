# %% [markdown]
# # **Colour codes for cmap.**
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ca19c3f-d7bb-4b14-b0b0-c1c7c96dc28f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ca19c3f-d7bb-4b14-b0b0-c1c7c96dc28f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import skimage.io
import skimage.color
import skimage.filters
#%matplotlib widget

# %%
image = skimage.io.imread("maize-root-cluster.jpg")

fig, ax = plt.subplots()
plt.imshow(image)

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "gray")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "spring")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "winter")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "hot")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "cool")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "viridis")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "inferno")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "Spectral")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "PiYG")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "bwr")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "twilight")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "Pastel1")

# %%
gray_image = skimage.color.rgb2gray(image)

blurred_image = skimage.filters.gaussian(gray_image,sigma = 2.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image,cmap = "Accent")

# %%
#shows the histogram of the blurred images
histogram, bin_edges = np.histogram(blurred_image, bins = 256, range = (0,1))
fig, ax = plt.subplots()
plt.plot(bin_edges[0:-1], histogram)
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.xlim(0,1.0)
# Out:
# (0.0, 1.0)

# %%
#perform automatic thresholding
t = skimage.filters.threshold_otsu(blurred_image)
print("Found automatic threshold t = {}.".format(t))
# Out:
# Found automatic threshold t = 0.3969217751617983.

# %%
binary_mask = blurred_image > t
fig, ax = plt.subplots()
plt.imshow(binary_mask, cmap = 'gray')

# %%
#binary mask to select the foreground
selection = image.copy()
selection[~binary_mask] = 0

fig,ax = plt.subplots()
plt.imshow(selection)
